# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv('audi.csv')

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
x = df.iloc[:,[0,1,3,4,5,6,7,8]]
x.head()
# Out:
#   model  year transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019       Manual     1998   Petrol  145  49.6         1.0

# %%
y = df.iloc[:,[2]]
y
# Out:
#        price
# 0      12500
# 1      16500
# 2      11000
# 3      16800
# 4      17300
# ...      ...
# 10663  16999
# 10664  16999
# 10665  17199
# 10666  19499
# 10667  15999
#
# [10668 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x['model']=le.fit_transform(x['model'])
le1 = LabelEncoder()
x['fuelType']=le.fit_transform(x['fuelType'])
# Out:
# C:\Users\sies\AppData\Local\Temp\ipykernel_16648\3715952254.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['model']=le.fit_transform(x['model'])
# C:\Users\sies\AppData\Local\Temp\ipykernel_16648\3715952254.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['fuelType']=le.fit_transform(x['fuelType'])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(transformers = [('encoder',OneHotEncoder(),[2])],remainder = 'passthrough')
x = ct.fit_transform(x)

# %%
x
# Out:
# array([[  0. ,   1. ,   0. , ..., 150. ,  55.4,   1.4],
#        [  1. ,   0. ,   0. , ...,  20. ,  64.2,   2. ],
#        [  0. ,   1. ,   0. , ...,  30. ,  55.4,   1.4],
#        ...,
#        [  0. ,   1. ,   0. , ..., 150. ,  49.6,   1. ],
#        [  1. ,   0. ,   0. , ..., 150. ,  47.9,   1.4],
#        [  0. ,   1. ,   0. , ..., 150. ,  47.9,   1.4]])
